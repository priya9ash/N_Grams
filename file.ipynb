# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("train.csv")

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\debas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
df=pd.read_csv('train.csv')

# %%
corpus=[]
for i in range(0,len(df)):
    review=re.sub('^[a-zA-Z]'," ",df['sms'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english') ]
    review=" ".join(review)
    corpus.append(review)

# %%
## Create the bag of Words model with ngram
from sklearn.feature_extraction.text import CountVectorizer
## for Binary BOW  enable binary=True
cv = CountVectorizer(max_features=100, binary = True ,ngram_range=(3,4))
X= cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'like lt gt': 37,
#  'orry ll call': 53,
#  'll call later': 39,
#  'orry ll call later': 54,
#  'call custom servic': 10,
#  'custom servic repres': 23,
#  'guarante 1000 cash': 32,
#  'call custom servic repres': 11,
#  'prize guaranteed call': 62,
#  'speak live oper': 80,
#  'live oper claim': 38,
#  'speak live oper claim': 81,
#  'bonu caller prize': 9,
#  'receiv 350 award': 63,
#  'rgent tri contact': 70,
#  'lt decimal gt': 42,
#  'secret admir look': 76,
#  'look make contact': 40,
#  'make contact find': 45,
#  'contact find reveal': 19,
#  'find reveal think': 28,
#  'reveal think ur': 67,
#  'think ur special': 85,
#  'ur special cal': 97,
#  'secret admir look make': 77,
#  'look make contact find': 41,
#  'make contact find reveal': 46,
#  'contact find reveal think': 20,
#  'find reveal think ur': 29,
#  'reveal think ur special': 68,
#  'think ur special cal': 86,
#  'draw txt music': 24,
#  'txt music 87066': 92,
#  'draw txt music 87066': 25,
#  '750 anytim network': 5,
#  'repli call 08000930705': 66,
#  'cant pick phone': 12,
#  'pick phone right': 57,
#  'phone right now': 55,
#  'right now pl': 72,
#  'now pl send': 51,
#  'pl send messag': 59,
#  'cant pick phone right': 13,
#  'pick phone right now': 58,
#  'phone right now pl': 56,
#  'right now pl send': 73,
#  'now pl send messag': 52,
#  'hg suite342 2land': 34,
#  'suite342 2land row': 84,
#  'hg suite342 2land row': 35,
#  'lt gt min': 44,
#  'rgent mobil number': 69,
#  'mobil number award': 49,
#  '2000 prize guaranteed': 1,
#  'land line claim': 36,
#  'claim 3030 valid': 16,
#  '3030 valid 12hr': 4,
#  '2000 prize guaranteed call': 2,
#  'claim 3030 valid 12hr': 17,
#  'lt gt lt': 43,
#  'gt lt gt': 31,
#  'rivate 2003 account': 74,
#  '2003 account statement': 3,
#  'show 800 un': 78,
#  '800 un redeem': 6,
#  'un redeem points': 93,
#  'redeem points call': 64,
#  'rivate 2003 account statement': 75,
#  'show 800 un redeem': 79,
#  '800 un redeem points': 7,
#  'un redeem points call': 94,
#  '1000 cash 2000': 0,
#  'happi new year': 33,
#  'everi wk txt': 27,
#  'ree 1st week': 65,
#  'nokia tone ur': 50,
#  'everi week txt': 26,
#  'www getzed co': 98,
#  'getzed co uk': 30,
#  'www getzed co uk': 99,
#  'cash await collect': 14,
#  'await collect sae': 8,
#  'cash await collect sae': 15,
#  'stop text call': 82,
#  'stop text call 08712460324': 83,
#  'tri contact today': 90,
#  'contact today draw': 21,
#  'today draw show': 87,
#  'rgent tri contact today': 71,
#  'tri contact today draw': 91,
#  'contact today draw show': 22,
#  'tone ur mob': 88,
#  'ur mob everi': 95,
#  'mob everi week': 47,
#  'tone ur mob everi': 89,
#  'ur mob everi week': 96,
#  'mob everi week txt': 48,
#  'prize claim easy': 60,
#  'claim easy call': 18,
#  'prize claim easy call': 61}

# %%
Y=df['label']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initialize and train the model
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.885201793721973
